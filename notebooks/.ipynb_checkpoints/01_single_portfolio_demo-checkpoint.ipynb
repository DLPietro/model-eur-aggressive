# %%
# 0. Import base
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import sys
sys.path.append("model-eur-aggressive")
from .loaders import load_portfolio_csv
from core.asset import Asset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 9
#       7 import sys
#       8 sys.path.append("model-eur-aggressive")
# ----> 9 from .loaders import load_portfolio_csv
#      10 from core.asset import Asset
#
# ImportError: attempted relative import with no known parent package

# %%
# Downloading portfolio
df_port = load_portfolio_csv("../data/model_eur_aggressive_clean.csv")
print("Portfolio loaded:")
print(df_port)
print(f"\nTotal weight: {df_port['allocation_w'].sum():.1%}")
print(f"Assets: {len(df_port)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Downloading portfolio
# ----> 2 df_port = load_portfolio_csv("../data/model_eur_aggressive_clean.csv")
#       3 print("Portfolio loaded:")
#       4 print(df_port)
#
# NameError: name 'load_portfolio_csv' is not defined
